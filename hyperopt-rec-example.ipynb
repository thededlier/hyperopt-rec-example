# %%
# !pip install hyperopt

# %%
from surprise import SVD
from surprise import KNNBasic
from surprise import Dataset
from surprise.model_selection import cross_validate

data = Dataset.load_builtin('ml-100k')

# %% [markdown]
# ## Manual usage

# %%
algo = SVD()

# Run 5-fold cross-validation and print results
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9426  0.9364  0.9374  0.9362  0.9396  0.9384  0.0024
# MAE (testset)     0.7407  0.7368  0.7379  0.7385  0.7426  0.7393  0.0021
# Fit time          9.91    10.02   7.53    5.81    6.09    7.87    1.80
# Test time         0.31    0.31    0.26    0.13    0.18    0.24    0.07
# {'test_rmse': array([0.94257595, 0.93635922, 0.93741969, 0.93622632, 0.93964228]),
#  'test_mae': array([0.74068396, 0.73680666, 0.73794365, 0.73848225, 0.7426143 ]),
#  'fit_time': (9.909649133682251,
#   10.018833637237549,
#   7.5276265144348145,
#   5.814746141433716,
#   6.092000961303711),
#  'test_time': (0.31347203254699707,
#   0.31253695487976074,
#   0.26464223861694336,
#   0.1318800449371338,
#   0.18134117126464844)}

# %%
algo = KNNBasic()

cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)['test_rmse'].mean()
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9699  0.9883  0.9783  0.9847  0.9719  0.9786  0.0071
# MAE (testset)     0.7659  0.7817  0.7707  0.7789  0.7675  0.7729  0.0063
# Fit time          0.76    1.00    1.05    0.98    1.00    0.96    0.10
# Test time         4.64    7.08    7.03    6.96    6.81    6.51    0.94
# 0.978622233312796

# %% [markdown]
# ## Hyper parameter tuning

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %%
similarity_options_space = {
    'name': hp.choice('name', ['cosine', 'msd', 'pearson', 'pearson_baseline']),
    'user_based': hp.choice('user_based', [False, True]),
    'shrinkage': hp.choice('shrinkage', range(1, 300))
}

svd_space = {
    'n_factors': hp.choice('n_factors', range(1, 100)),
    'n_epochs': hp.choice('n_epochs', range(1, 20)),
    'lr_all': hp.uniform('lr_all', 0.001, 0.3),
    'reg_all': hp.uniform('reg_all', 0.001, 0.3),
}

knn_space = {
    'k': hp.choice('k', range(1,100))
}

# %%
def hyperopt_svd(params):
    print(params)
    algo = SVD(n_factors=params['n_factors'], n_epochs=params['n_epochs'], lr_all=params['lr_all'], reg_all=params['reg_all'])
    return cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)['test_rmse'].mean()

def objective_svd(params):
    rmse = hyperopt_svd(params)
    return {'loss': rmse, 'status': STATUS_OK}

space = svd_space 

trials = Trials()
svd_best = fmin(objective_svd, space, algo=tpe.suggest, max_evals=20, trials=trials)
print('best:')
print(svd_best)
# Out:
# {'lr_all': 0.2512500575841037, 'n_epochs': 14, 'n_factors': 54, 'reg_all': 0.1898828330768992}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0723  1.0641  1.0692  1.0629  1.0661  1.0669  0.0034
# MAE (testset)     0.8502  0.8410  0.8468  0.8433  0.8445  0.8452  0.0031
# Fit time          4.72    4.54    4.43    4.77    4.90    4.67    0.17
# Test time         0.38    0.21    0.32    0.30    0.37    0.31    0.06
# {'lr_all': 0.19896086075616254, 'n_epochs': 2, 'n_factors': 80, 'reg_all': 0.1988757966861109}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0311  1.0410  1.0394  1.0324  1.0455  1.0379  0.0054
# MAE (testset)     0.8179  0.8291  0.8259  0.8206  0.8317  0.8250  0.0051
# Fit time          0.94    0.95    0.96    0.93    0.91    0.94    0.02
# Test time         0.25    0.24    0.36    0.28    0.40    0.31    0.06
# {'lr_all': 0.07023345040438964, 'n_epochs': 5, 'n_factors': 94, 'reg_all': 0.13126570420237804}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9430  0.9412  0.9520  0.9485  0.9458  0.9461  0.0039
# MAE (testset)     0.7489  0.7460  0.7558  0.7518  0.7515  0.7508  0.0033
# Fit time          2.54    2.43    2.46    2.51    2.66    2.52    0.08
# Test time         0.34    0.24    0.37    0.32    0.31    0.31    0.04
# {'lr_all': 0.2676912502413544, 'n_epochs': 13, 'n_factors': 4, 'reg_all': 0.002157698338161638}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.8463  1.8528  1.8492  1.8567  1.8529  1.8516  0.0036
# MAE (testset)     1.4662  1.4715  1.4623  1.4784  1.4724  1.4701  0.0055
# Fit time          1.76    1.91    1.83    1.77    1.87    1.83    0.06
# Test time         0.31    0.25    0.32    0.25    0.37    0.30    0.05
# {'lr_all': 0.021136620875642217, 'n_epochs': 1, 'n_factors': 16, 'reg_all': 0.15932164878425023}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9646  0.9600  0.9731  0.9686  0.9688  0.9670  0.0045
# MAE (testset)     0.7697  0.7668  0.7780  0.7721  0.7719  0.7717  0.0037
# Fit time          0.26    0.26    0.27    0.26    0.29    0.27    0.01
# Test time         0.36    0.26    0.32    0.28    0.37    0.32    0.04
# {'lr_all': 0.2395314695971923, 'n_epochs': 3, 'n_factors': 67, 'reg_all': 0.2580532218092017}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0433  1.0532  1.0553  1.0568  1.0529  1.0523  0.0047
# MAE (testset)     0.8297  0.8354  0.8394  0.8406  0.8363  0.8363  0.0038
# Fit time          1.18    1.24    1.21    1.30    1.26    1.24    0.04
# Test time         0.25    0.21    0.34    0.27    0.36    0.28    0.06
# {'lr_all': 0.07238338404979891, 'n_epochs': 14, 'n_factors': 2, 'reg_all': 0.07524669706687288}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9567  0.9479  0.9520  0.9467  0.9457  0.9498  0.0041
# MAE (testset)     0.7541  0.7469  0.7498  0.7414  0.7460  0.7476  0.0042
# Fit time          1.80    1.84    1.95    1.96    1.96    1.90    0.07
# Test time         0.32    0.24    0.34    0.26    0.36    0.30    0.05
# {'lr_all': 0.0865731845627221, 'n_epochs': 14, 'n_factors': 25, 'reg_all': 0.20475048707255472}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9716  0.9786  0.9592  0.9604  0.9719  0.9683  0.0074
# MAE (testset)     0.7741  0.7783  0.7628  0.7638  0.7718  0.7702  0.0060
# Fit time          3.23    3.21    3.25    3.33    3.05    3.21    0.09
# Test time         0.35    0.27    0.33    0.27    0.35    0.32    0.04
# {'lr_all': 0.056260643898405835, 'n_epochs': 1, 'n_factors': 45, 'reg_all': 0.02964734897149103}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9617  0.9645  0.9602  0.9592  0.9636  0.9618  0.0020
# MAE (testset)     0.7603  0.7618  0.7607  0.7584  0.7622  0.7607  0.0013
# Fit time          0.34    0.41    0.40    0.33    0.39    0.37    0.03
# Test time         0.37    0.28    0.40    0.24    0.36    0.33    0.06
# {'lr_all': 0.07033139681039555, 'n_epochs': 12, 'n_factors': 85, 'reg_all': 0.020576848808848015}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0132  1.0115  1.0158  1.0073  1.0075  1.0111  0.0033
# MAE (testset)     0.7957  0.7972  0.7942  0.7896  0.7886  0.7931  0.0034
# Fit time          5.69    5.42    5.41    5.34    5.40    5.45    0.12
# Test time         0.38    0.24    0.34    0.27    0.31    0.31    0.05
# {'lr_all': 0.03769757767995167, 'n_epochs': 7, 'n_factors': 75, 'reg_all': 0.13126174228455226}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9340  0.9311  0.9262  0.9367  0.9437  0.9343  0.0058
# MAE (testset)     0.7413  0.7385  0.7355  0.7433  0.7494  0.7416  0.0047
# Fit time          3.01    2.82    2.63    2.84    2.58    2.78    0.15
# Test time         0.33    0.23    0.26    0.26    0.30    0.28    0.04
# {'lr_all': 0.24899130136820388, 'n_epochs': 13, 'n_factors': 47, 'reg_all': 0.23482563424337852}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0495  1.0493  1.0521  1.0628  1.0487  1.0525  0.0053
# MAE (testset)     0.8336  0.8316  0.8359  0.8435  0.8327  0.8355  0.0043
# Fit time          3.59    3.74    4.59    4.06    4.44    4.08    0.38
# Test time         0.32    0.15    0.40    0.27    0.37    0.30    0.09
# {'lr_all': 0.18718758147126832, 'n_epochs': 3, 'n_factors': 11, 'reg_all': 0.29258646239338676}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0141  1.0290  1.0200  1.0266  1.0323  1.0244  0.0065
# MAE (testset)     0.8052  0.8198  0.8135  0.8180  0.8220  0.8157  0.0059
# Fit time          0.60    0.61    0.58    0.56    0.57    0.58    0.02
# Test time         0.38    0.34    0.35    0.28    0.37    0.34    0.04
# {'lr_all': 0.23593460503423527, 'n_epochs': 8, 'n_factors': 75, 'reg_all': 0.23224372851309458}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0450  1.0333  1.0462  1.0312  1.0450  1.0402  0.0065
# MAE (testset)     0.8270  0.8186  0.8319  0.8186  0.8306  0.8253  0.0057
# Fit time          3.23    3.49    3.50    3.38    3.16    3.35    0.13
# Test time         0.28    0.21    0.35    0.25    0.33    0.29    0.05
# {'lr_all': 0.11587639486443706, 'n_epochs': 11, 'n_factors': 15, 'reg_all': 0.2325587424103848}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9797  0.9866  0.9948  0.9852  0.9908  0.9874  0.0051
# MAE (testset)     0.7798  0.7881  0.7941  0.7853  0.7888  0.7872  0.0047
# Fit time          1.96    1.95    2.07    2.09    2.04    2.02    0.05
# Test time         0.25    0.25    0.40    0.28    0.35    0.31    0.06
# {'lr_all': 0.06355155055745894, 'n_epochs': 18, 'n_factors': 85, 'reg_all': 0.09875328760102649}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9323  0.9268  0.9301  0.9281  0.9313  0.9297  0.0020
# MAE (testset)     0.7377  0.7340  0.7371  0.7310  0.7359  0.7352  0.0024
# Fit time          7.59    7.82    6.69    7.31    8.11    7.50    0.48
# Test time         0.46    0.27    0.35    0.28    0.28    0.33    0.07
# {'lr_all': 0.24124663056293508, 'n_epochs': 3, 'n_factors': 12, 'reg_all': 0.10487491330027118}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0823  1.0800  1.0876  1.1042  1.0862  1.0881  0.0085
# MAE (testset)     0.8506  0.8506  0.8537  0.8698  0.8522  0.8554  0.0073
# Fit time          0.57    0.57    0.45    0.43    0.47    0.50    0.06
# Test time         0.25    0.26    0.34    0.19    0.30    0.27    0.05
# {'lr_all': 0.21376578226000567, 'n_epochs': 1, 'n_factors': 89, 'reg_all': 0.1377156550306076}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0407  1.0446  1.0501  1.0463  1.0383  1.0440  0.0042
# MAE (testset)     0.8265  0.8284  0.8334  0.8272  0.8234  0.8278  0.0032
# Fit time          0.51    0.53    0.57    0.51    0.58    0.54    0.03
# Test time         0.24    0.26    0.37    0.24    0.32    0.29    0.05
# {'lr_all': 0.08266521788693008, 'n_epochs': 9, 'n_factors': 4, 'reg_all': 0.2888153889440308}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9807  0.9792  0.9763  0.9802  0.9701  0.9773  0.0039
# MAE (testset)     0.7828  0.7811  0.7801  0.7827  0.7749  0.7803  0.0029
# Fit time          1.35    1.47    1.36    1.27    1.16    1.32    0.10
# Test time         0.33    0.26    0.35    0.28    0.22    0.29    0.05
# {'lr_all': 0.10640844618465518, 'n_epochs': 19, 'n_factors': 12, 'reg_all': 0.1364201229262274}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9661  0.9508  0.9656  0.9607  0.9658  0.9618  0.0058
# MAE (testset)     0.7633  0.7537  0.7642  0.7600  0.7664  0.7615  0.0045
# Fit time          2.73    2.80    2.99    2.93    2.84    2.86    0.09
# Test time         0.31    0.24    0.32    0.14    0.31    0.26    0.07
# 100%|███████████████████████████████████████████████████| 20/20 [04:59<00:00, 14.96s/it, best loss: 0.9297123532744322]
# best:
# {'lr_all': 0.06355155055745894, 'n_epochs': 17, 'n_factors': 84, 'reg_all': 0.09875328760102649}

# %%
def hyperopt_knn_basic(params):
    print(params)
    sim_options = {
        'name': params['name'],
        'user_based': params['user_based'],
        'shrinkage': params['shrinkage']
    }
    
    algo = KNNBasic(k=params['k'], sim_options=sim_options)
    return cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)['test_rmse'].mean()

def objective_knn_basic(params):
    rmse = hyperopt_knn_basic(params)
    return {'loss': rmse, 'status': STATUS_OK}

space = {**similarity_options_space, **knn_space} 

trials = Trials()
knn_best = fmin(objective_knn_basic, space, algo=tpe.suggest, max_evals=20, trials=trials)
print('best:')
print(knn_best)
# Out:
# {'k': 37, 'name': 'msd', 'shrinkage': 246, 'user_based': False}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9730  0.9788  0.9718  0.9777  0.9706  0.9744  0.0032
# MAE (testset)     0.7671  0.7742  0.7700  0.7723  0.7658  0.7699  0.0031
# Fit time          1.37    1.42    1.38    1.36    1.28    1.36    0.05
# Test time         7.60    7.94    7.77    7.65    7.47    7.69    0.16
# {'k': 58, 'name': 'pearson', 'shrinkage': 206, 'user_based': True}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0039  1.0093  1.0069  1.0147  1.0134  1.0096  0.0040
# MAE (testset)     0.7985  0.8022  0.7987  0.8045  0.8051  0.8018  0.0028
# Fit time          3.83    4.31    4.17    4.02    4.05    4.07    0.16
# Test time         8.02    8.54    8.24    7.85    7.98    8.13    0.24
# {'k': 47, 'name': 'pearson', 'shrinkage': 4, 'user_based': True}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0115  1.0171  1.0025  1.0136  1.0105  1.0110  0.0048
# MAE (testset)     0.8042  0.8084  0.7949  0.8032  0.8033  0.8028  0.0044
# Fit time          4.05    4.24    3.80    3.71    4.20    4.00    0.21
# Test time         7.62    7.55    8.25    8.13    7.15    7.74    0.40
# {'k': 88, 'name': 'cosine', 'shrinkage': 39, 'user_based': False}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0286  1.0296  1.0138  1.0313  1.0221  1.0251  0.0065
# MAE (testset)     0.8171  0.8152  0.8051  0.8160  0.8115  0.8130  0.0044
# Fit time          4.78    4.38    5.42    3.93    4.74    4.65    0.49
# Test time         10.93   9.58    10.12   9.12    10.33   10.01   0.62
# {'k': 53, 'name': 'pearson_baseline', 'shrinkage': 174, 'user_based': True}
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0024  0.9932  0.9991  1.0039  0.9960  0.9989  0.0039
# MAE (testset)     0.7925  0.7849  0.7918  0.7925  0.7898  0.7903  0.0029
# Fit time          3.66    3.13    3.70    3.85    3.73    3.62    0.25
# Test time         7.02    7.53    7.38    7.92    7.93    7.55    0.34
# {'k': 57, 'name': 'pearson_baseline', 'shrinkage': 291, 'user_based': True}
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9974  1.0091  1.0059  0.9964  0.9895  0.9996  0.0070
# MAE (testset)     0.7907  0.7953  0.7968  0.7886  0.7840  0.7911  0.0046
# Fit time          3.86    3.90    3.66    4.17    3.96    3.91    0.17
# Test time         7.55    7.43    7.59    8.11    9.88    8.11    0.91
# {'k': 32, 'name': 'msd', 'shrinkage': 135, 'user_based': False}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9700  0.9720  0.9799  0.9736  0.9768  0.9744  0.0035
# MAE (testset)     0.7668  0.7667  0.7747  0.7690  0.7728  0.7700  0.0032
# Fit time          1.34    1.38    1.41    1.27    1.44    1.37    0.06
# Test time         6.85    7.38    6.95    7.63    7.52    7.27    0.31
# {'k': 32, 'name': 'pearson', 'shrinkage': 295, 'user_based': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0460  1.0508  1.0429  1.0475  1.0448  1.0464  0.0026
# MAE (testset)     0.8356  0.8422  0.8356  0.8422  0.8373  0.8386  0.0030
# Fit time          5.48    5.70    6.20    6.44    5.71    5.91    0.36
# Test time         7.38    8.19    7.70    7.93    7.77    7.80    0.27
# {'k': 94, 'name': 'cosine', 'shrinkage': 152, 'user_based': True}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0218  1.0177  1.0161  1.0240  1.0073  1.0174  0.0058
# MAE (testset)     0.8140  0.8073  0.8052  0.8091  0.7982  0.8068  0.0052
# Fit time          3.16    3.46    3.27    3.08    3.08    3.21    0.15
# Test time         9.78    8.51    9.43    8.46    8.97    9.03    0.51
# {'k': 64, 'name': 'msd', 'shrinkage': 31, 'user_based': False}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9770  0.9736  0.9743  0.9777  0.9820  0.9769  0.0030
# MAE (testset)     0.7742  0.7724  0.7734  0.7722  0.7756  0.7736  0.0012
# Fit time          1.18    1.29    1.23    1.28    1.39    1.27    0.07
# Test time         8.74    8.45    7.97    8.83    9.48    8.69    0.49
# {'k': 67, 'name': 'pearson_baseline', 'shrinkage': 26, 'user_based': False}
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9987  1.0002  1.0003  0.9921  1.0040  0.9990  0.0039
# MAE (testset)     0.7896  0.7917  0.7929  0.7867  0.7947  0.7911  0.0028
# Fit time          5.09    4.97    5.07    4.91    5.06    5.02    0.07
# Test time         8.85    8.95    9.49    10.43   9.58    9.46    0.57
# {'k': 11, 'name': 'pearson_baseline', 'shrinkage': 245, 'user_based': True}
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0097  1.0180  1.0157  1.0122  1.0159  1.0143  0.0029
# MAE (testset)     0.7995  0.8050  0.8053  0.8038  0.8001  0.8028  0.0024
# Fit time          3.79    3.19    3.92    3.94    3.75    3.72    0.28
# Test time         4.83    5.26    5.73    5.18    4.83    5.17    0.33
# {'k': 53, 'name': 'msd', 'shrinkage': 279, 'user_based': False}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9780  0.9730  0.9752  0.9792  0.9720  0.9755  0.0028
# MAE (testset)     0.7730  0.7718  0.7694  0.7736  0.7709  0.7717  0.0015
# Fit time          1.40    1.40    1.38    1.51    1.38    1.41    0.05
# Test time         9.37    9.17    9.54    9.21    9.59    9.37    0.17
# {'k': 9, 'name': 'msd', 'shrinkage': 251, 'user_based': False}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0213  1.0119  1.0262  1.0226  1.0223  1.0209  0.0048
# MAE (testset)     0.8066  0.7973  0.8076  0.8084  0.8034  0.8047  0.0041
# Fit time          1.35    1.41    1.44    1.27    1.31    1.36    0.06
# Test time         5.47    5.54    5.34    5.40    5.56    5.46    0.08
# {'k': 85, 'name': 'pearson', 'shrinkage': 242, 'user_based': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0349  1.0271  1.0289  1.0252  1.0359  1.0304  0.0042
# MAE (testset)     0.8297  0.8221  0.8251  0.8169  0.8301  0.8248  0.0050
# Fit time          5.74    5.66    6.11    6.29    6.31    6.02    0.27
# Test time         9.19    9.63    10.10   10.36   10.21   9.90    0.43
# {'k': 75, 'name': 'pearson', 'shrinkage': 36, 'user_based': True}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0174  1.0113  1.0088  1.0072  1.0112  1.0112  0.0035
# MAE (testset)     0.8079  0.8035  0.8015  0.8000  0.8027  0.8031  0.0027
# Fit time          4.18    4.09    3.79    4.04    4.29    4.08    0.17
# Test time         9.01    9.51    7.99    9.00    9.27    8.96    0.52
# {'k': 53, 'name': 'pearson', 'shrinkage': 160, 'user_based': True}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0091  1.0090  1.0033  1.0177  1.0176  1.0113  0.0056
# MAE (testset)     0.8008  0.8019  0.7982  0.8067  0.8073  0.8030  0.0035
# Fit time          4.02    4.18    4.09    4.15    4.36    4.16    0.11
# Test time         7.66    7.27    8.58    7.77    7.38    7.73    0.46
# {'k': 88, 'name': 'pearson_baseline', 'shrinkage': 135, 'user_based': True}
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using
# als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9963  1.0013  0.9990  0.9995  0.9954  0.9983  0.0022
# MAE (testset)     0.7894  0.7937  0.7905  0.7927  0.7858  0.7904  0.0028
# Fit time          3.48    3.62    3.69    3.65    3.75    3.64    0.09
# Test time         8.14    8.27    8.23    7.84    8.49    8.19    0.21
# {'k': 74, 'name': 'cosine', 'shrinkage': 85, 'user_based': False}
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0222  1.0273  1.0223  1.0216  1.0280  1.0243  0.0028
# MAE (testset)     0.8097  0.8132  0.8114  0.8092  0.8116  0.8110  0.0014
# Fit time          4.98    4.47    3.34    4.69    5.14    4.53    0.64
# Test time         9.85    7.68    9.07    9.26    12.56   9.69    1.60
# {'k': 65, 'name': 'pearson', 'shrinkage': 274, 'user_based': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0328  1.0282  1.0303  1.0343  1.0330  1.0317  0.0022
# MAE (testset)     0.8239  0.8248  0.8245  0.8272  0.8279  0.8257  0.0016
# Fit time          5.83    6.02    6.28    6.29    6.23    6.13    0.18
# Test time         9.27    9.50    8.73    9.27    9.70    9.29    0.32
# 100%|███████████████████████████████████████████████████| 20/20 [20:24<00:00, 61.21s/it, best loss: 0.9743817342234958]
# best:
# {'k': 36, 'name': 1, 'shrinkage': 245, 'user_based': 0}

# %% [markdown]
# Using the best parameters

# %%
algo = SVD(n_factors=svd_best['n_factors'], n_epochs=svd_best['n_epochs'], lr_all=svd_best['lr_all'], reg_all=svd_best['reg_all'])
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9299  0.9291  0.9296  0.9331  0.9291  0.9302  0.0015
# MAE (testset)     0.7334  0.7357  0.7340  0.7364  0.7352  0.7349  0.0011
# Fit time          7.07    7.56    7.65    7.51    7.66    7.49    0.22
# Test time         0.19    0.39    0.28    0.32    0.31    0.30    0.06
# {'test_rmse': array([0.92988825, 0.92907645, 0.92955652, 0.93312181, 0.92913651]),
#  'test_mae': array([0.73337068, 0.73567309, 0.73397269, 0.73643192, 0.73524481]),
#  'fit_time': (7.073363542556763,
#   7.560258388519287,
#   7.650027275085449,
#   7.509051084518433,
#   7.656406402587891),
#  'test_time': (0.1905984878540039,
#   0.38620615005493164,
#   0.2801854610443115,
#   0.318373441696167,
#   0.31432676315307617)}

# %%
best_sim_options = {
    'name': 'msd',
    'user_based': False,
    'shrinkage': knn_best['shrinkage']
}

algo = KNNBasic(k=knn_best['k'], sim_options=best_sim_options)
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9726  0.9865  0.9776  0.9635  0.9733  0.9747  0.0075
# MAE (testset)     0.7700  0.7766  0.7707  0.7620  0.7689  0.7696  0.0047
# Fit time          1.20    1.32    1.21    1.00    1.37    1.22    0.13
# Test time         8.26    6.99    5.70    6.83    9.22    7.40    1.22
# {'test_rmse': array([0.97258777, 0.9864923 , 0.97763001, 0.96348447, 0.97332189]),
#  'test_mae': array([0.76999454, 0.77655068, 0.77073785, 0.76197556, 0.76885721]),
#  'fit_time': (1.202993392944336,
#   1.3241088390350342,
#   1.2092125415802002,
#   0.9988794326782227,
#   1.3740673065185547),
#  'test_time': (8.262562274932861,
#   6.9908294677734375,
#   5.6955389976501465,
#   6.833252429962158,
#   9.215123176574707)}
